# %% [markdown]
# Importing BeautifulSoup Class

# %%
import requests
from bs4 import BeautifulSoup

# %% [markdown]
# Importing CSV to export data at the end

# %%
import csv
import re
import urllib.parse
from geopy.geocoders import Nominatim
import pandas as pd

# %% [markdown]
# # quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt

# %% [markdown]
# ;Import txt file

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    print(soup)
# Out:
# <!DOCTYPE html>
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <meta content="" name="description"/>
# <meta content="" name="author"/>
# <link href="/favicon.ico" rel="icon"/>
# <title>Quantum Blog</title>
# <!-- Bootstrap core CSS and Material Bootstrap -->
# <link href="/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="/css/font-awesome.min.css" rel="stylesheet"/>
# <link href="/css/bootstrap-material-design.css" rel="stylesheet"/>
# <link href="/css/ripples.min.css" rel="stylesheet"/>
# <link href="/css/material-scrolltop.css" rel="stylesheet"/>
# <!-- Custom styles for this template -->
# <link href="/css/material-blog.css" rel="stylesheet"/>
# <!-- Fonts -->
# <!-- <link href="https://fonts.googleapis.com/css?family=Roboto:300,400,500,700" rel="stylesheet"> -->
# ...

# %% [markdown]
# Print Title of webpage

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    print(soup.title)
# Out:
# <title>Quantum Blog</title>

# %% [markdown]
# Finding elements on the webpage using class name

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    blog_posts = soup.find_all("section", class_="blog-post")
    for blog_post in blog_posts:
      print(blog_post, end="\n"*2)
# Out:
# <section class="blog-post">
# <div class="panel panel-default">
# <!-- <img src="img/fashion/unsplash-2.jpg" class="img-responsive" /> -->
# <img class="img-responsive" src="/target/logo/77"/>
# <div class="panel-body">
# <div class="blog-post-meta">
# <span class="label label-light label-info">1100GB </span>
# <p class="blog-post-date pull-right">2022-09-01</p>
# </div>
# <div class="blog-post-content">
# <a href="/target/institutoagrariodominicano">
# <h2 class="blog-post-title">
#                     Instituto Agrario Dominicano
#                 </h2>
# </a>
# <p>
#                   The Dominican Agrarian Institute is a decentralized government agency under the Ministry of Agriculture,established by Law No. 5879 as of April 27, 1962, with the aim of carrying out agrarian reform programs throughout the national geography by seizing and distributing land to peasants to transform the structure and agricultural production, improving living conditions in a Dominican villages.
# ...

# %% [markdown]
# Finding specific elements in each class

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    blog_posts = soup.find_all("section", class_="blog-post")
    count = 0
    for blog_post in blog_posts:
      count = count + 1
      print(str(count) + ".")
      blog_post_title = (blog_post.find('h2', attrs={'class': 'blog-post-title'}).text)
      print(blog_post_title)
# Out:
# 1.
#
#                     Instituto Agrario Dominicano
#
# 2.
#
#                     Shaw & Slavsky
#
# 3.
#
#                     BEESENSE
#
# 4.
#
#                     Broshuis | Driving innovation
#
# 5.
#
#                     ZEUS Scientific
#
# 6.
#
#                     Shred Station
#
# 7.
#
#                     Florida Department of Veterans' Affairs
#
# 8.
#
#                     Valley Rentals
#
# 9.
#
#                     Drive Products
#
# 10.
#
#                     Tehama County Social Services
#
# 11.
#
#                     Camden City School District
#
# 12.
#
#                     JetStar
#
# 13.
#
#                     InfoTek Consulting Services
#
# 14.
#
#                     Maple Lodge Farms
#
# 15.
#
#                     Biotique
#
# 16.
#
#                     PRIDE Community Services
#
# 17.
#
#                     UABL S.A.
#
# 18.
#
#                     Avante Health Solutions
#
# 19.
#
#                     Moskowitz, Mandell & Salim, P.A.
#
# ...

# %% [markdown]
# Finding the Industries that is attacked

# %%
#Creating a dictionary storing keywords and phrases pertaining to each industry 
industries = {'GovernmentAgency': ['national','instituto','government', 'defense', 'homeland security','federal','state', 'social', 'county', 'confederation','ministry'], 
              'Agriculture': ['agriculture', 'crop', 'farms'], 
              'Supermarket': ['supermarket', 'grocery'], 
              'Technology': ['technology-based','technology','wireless', 'communication', 'digital'],
              'Security': ['security', 'secure','intelligence', 'surveillance', 'reconnaissance'],
              'Motor/Vehicular': ['vehicles','driving','car','drive', 'motorcycles', 'snowmobiles'],
              'Medical': ['medical', 'health', 'hospital', 'clinic', 'pharmaceutical', 'pathology'],
              'RealEstate': ['estate'],
              'School': ['school', 'college'],
              'Airline': ['airline','flights'],
              'ConsultingServices': ['consulting'],
              'Cosmetics': ['cosmetics', 'suplements', 'beauty', 'skin care'],
              'NonProfitOrganisation': ['community', 'in need', 'communities', 'voluntary'],
              'Water': ['water'],
              'Legal': ['legal', 'law'],
              'HeavyMachineryManufacturer': ['forklifts'],
              'Accountancy': ['accountants'],
              'Pipes': ['tubular'],
              'Fuel/Oil': ['fuel', 'petrol','propance'],
              'Construction/Renovation': ['barrier', 'roofing', 'waterproofing', 'construction', 'building'],
              'Aerospace': ['turbine engine'],
              'Unions': ['union'],
              'DrinkManufacturer': ['drink'],
              'ConventionCentre': ['meeting', 'exhibition'],
              'Accessories': ['accessories'],
              'Glass': ['glass'],
              'Food': ['food'],
              'Welding': ['metal', 'material'],
              'Finance': ['commerce'],
              'Retailer': ['consumer'],
              'Diamond': ['diamond'],
              'Cinema/Movie': ['PVR Ltd.'], 
              'Multimedia': ['multimedia', 'television', 'productions', 'films', 'advertising'],
              'Drilling': ['drilling', 'rigs']}

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    blog_posts = soup.find_all("section", class_="blog-post")
    count = 0
    for blog_post in blog_posts:
      blog_post_date = (blog_post.find('p', attrs={'class': 'blog-post-date pull-right'}).text)
      if '2021' in blog_post_date:
        break

      industry = 'none found'
      count = count + 1
      print(str(count) + ".")
      blog_post_title = (blog_post.find('h2', attrs={'class': 'blog-post-title'}).text)
      print(blog_post_title)
      title = blog_post_title.split()

      for key in industries:
        for i in industries[key]:
          for j in title:
            if i == j.lower():
              industry = key
              break

      if industry == "none found":
        count_para =0
        for para in soup.find_all("p"):
          if '2022' not in para.get_text():
            count_para = count_para + 1
            if count == count_para:
              txt = (para.get_text()).split()
              for key in industries:
                for k in txt:
                  for i in industries[key]:
                    if i == k.lower():
                      industry = key
                      break


      print(industry)
# Out:
# 1.
#
#                     Instituto Agrario Dominicano
#
# GovernmentAgency
# 2.
#
#                     Shaw & Slavsky
#
# Supermarket
# 3.
#
#                     BEESENSE
#
# Security
# 4.
#
#                     Broshuis | Driving innovation
#
# Motor/Vehicular
# 5.
#
#                     ZEUS Scientific
#
# Medical
# 6.
#
#                     Shred Station
#
# Security
# 7.
#
#                     Florida Department of Veterans' Affairs
#
# GovernmentAgency
# 8.
#
#                     Valley Rentals
#
# RealEstate
# 9.
#
#                     Drive Products
#
# Motor/Vehicular
# 10.
#
#                     Tehama County Social Services
#
# GovernmentAgency
# 11.
#
#                     Camden City School District
#
# School
# 12.
#
#                     JetStar
#
# Airline
# 13.
#
#                     InfoTek Consulting Services
#
# ConsultingServices
# 14.
#
#                     Maple Lodge Farms
#
# Agriculture

# %% [markdown]
# Obtain industry of company

# %%
# query = "What is the location of " + "Instituto Agrario Dominicano"
 
# # for j in search(query, num=10, stop=10, pause=2):
# #     print(j)

# import urllib.request

# url = 'https://google.com/search?q=' + query

# request_result=requests.get(url)
  
# # Creating soup from the fetched request
# soup = BeautifulSoup(request_result.text,
#                          "html.parser")
# # print(soup)

# results = soup.find_all("h1", class_="Uo8X3b OhScic zsYMMe")
# for result in results:
#   print(results.text)

# %% [markdown]
# Obtain location of company

# %%
address = 'Instituto Agrario Dominicano'
url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'

response = requests.get(url).json()
latitude = response[0]["lat"]
longitude = response[0]["lon"]

print(latitude)
print(longitude)

geolocator = Nominatim()
location = geolocator.reverse(latitude + "," + longitude)

print(location.address)
# Out:
# 18.422594150000002
# -70.11518925
# /usr/local/lib/python3.7/dist-packages/geopy/geocoders/osm.py:143: UserWarning: Using Nominatim with the default "geopy/1.17.0" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   UserWarning
# Instituto Agrario Dominicano, Avenida Constitución, Los Molina, San Cristóbal, 91000, República Dominicana

# %% [markdown]
# Storing Data in CSV file

# %%
dataType = {'Data Type - Databases': ['databases', 'SQL', 'SAP'],
            'Data Type - Applications': ['applications', 'program'],
            'Data Type - Emails': ['emails', 'passwords'], 
            'Data Type - Source Code': ['code'],
            'Data Type - Business Information': ['projects', 'documents', 'resumes', 'contracts', 'commercial', 'insurance', 'statements', 'certificates', 'internal', 'signed'],
            'Data Type - Designs': ['drawings', 'designs', 'media', 'projects'],
            'Data Type - Financial Information': ['financial', 'accounting', 'balances', 'invoices', 'financials', 'tax', 'budgets', 'fiscal', 'bank'],
            'Data Type - Research Information': ['research', 'studies'],
            'Data Type - Employee Information': ['employees', 'personal', 'HR', 'payrolls', 'payroll', 'scans', 'vaccine', 'criminal', 'medication', 'numbers'],
            'Data Type - Customer Information': ['customer', 'address', 'client', 'numbers'],
            'Data Type - Company Information': ['company', 'duration', 'operation'],
            'Data Type - Backup Systems Information': ['backups'],
            'Data Type - Supply Systems Information': ['suppliers'],
            'Data Type - Business Deals Information': ['partners', 'contracts', 'clients', 'negotiations'],
            'Data Type - Manufacturing Information': ['manufacturing'],}

for key in dataType:
    print(key)
# Out:
# Data Type - Databases
# Data Type - Applications
# Data Type - Emails
# Data Type - Source Code
# Data Type - Business Information
# Data Type - Designs
# Data Type - Financial Information
# Data Type - Research Information
# Data Type - Employee Information
# Data Type - Customer Information
# Data Type - Company Information
# Data Type - Backup Systems Information
# Data Type - Supply Systems Information
# Data Type - Business Deals Information
# Data Type - Manufacturing Information

# %%
headers = (['Count','Company Targeted', 'Publish Date', 'Attacker', 'Industry', 'Latitude', 'Longitude', 'Location of Attack', 'Leak Size (In MB)'])
for key in dataType:
  headers.append(key)

print(headers)
# Out:
# ['Count', 'Company Targeted', 'Publish Date', 'Attacker', 'Industry', 'Latitude', 'Longitude', 'Location of Attack', 'Leak Size (In MB)', 'Data Type - Databases', 'Data Type - Applications', 'Data Type - Emails', 'Data Type - Source Code', 'Data Type - Business Information', 'Data Type - Designs', 'Data Type - Financial Information', 'Data Type - Research Information', 'Data Type - Employee Information', 'Data Type - Customer Information', 'Data Type - Company Information', 'Data Type - Backup Systems Information', 'Data Type - Supply Systems Information', 'Data Type - Business Deals Information', 'Data Type - Manufacturing Information']

# %%
with open("/content/quantum445bh3gzuyilxdzs5xdepf3b7lkcupswvkryf3n7hgzpxebid.txt") as f:
    soup = BeautifulSoup(f.read())
    blog_posts = soup.find_all("section", class_="blog-post")
    count = 0

    file = open('IntermediateOutput - Quantum and RansomEXX.csv', 'a', newline='', encoding='utf-8')
    writer = csv.writer(file)
    headers = (['Count','Company Targeted', 'Publish Date', 'Attacker', 'Industry', 'Latitude', 'Longitude', 'Location of Attack', 'Leak Size (In MB)'])
    for key in dataType:
      headers.append(key)
    writer.writerow(headers)
    file.close()

    for blog_post in blog_posts:

      blog_post_date = (blog_post.find('p', attrs={'class': 'blog-post-date pull-right'}).text)
      if '2021' in blog_post_date:
        break

      publish_Date = blog_post_date

      industry = 'none found'
      location = 'none found'
      attacker = 'Quantum Ransomware'
      latitude = 0
      longitude = 0
      count = count + 1

      blog_post_title = (blog_post.find('h2', attrs={'class': 'blog-post-title'}).text)
      blog_post_title = blog_post_title.lstrip()
      blog_post_title = blog_post_title.rstrip() 
      title = blog_post_title.split()

      for j in title:
        for key in industries:
          for i in industries[key]:
            if i == j.lower():
              industry = key
              break
      
      leak_size = (blog_post.find('span', attrs={'class': 'label label-light label-info'}).text)


      if "G" in leak_size:
        leak_size = ''.join(filter(str.isdigit, leak_size))
        leak_size = int(leak_size)
        leak_size = leak_size * 1000
      
      elif "T" in leak_size:
        leak_size = ''.join(filter(str.isdigit, leak_size))
        leak_size = int(leak_size)
        leak_size = leak_size * 1000000
      
      elif "M" in leak_size:
        leak_size = ''.join(filter(str.isdigit, leak_size))
        leak_size = int(leak_size)
        print(leak_size)

      if industry == "none found":
        count_para =0
        for para in soup.find_all("p"):
          if '2022' not in para.get_text():
            count_para = count_para + 1
            if count == count_para:
              new_string = re.sub(r'[^\w\s]', '', para.get_text())
              new_string = new_string.replace('of', '')
              txt = (new_string).split()
              for key in industries:
                for k in txt:
                  for i in industries[key]:
                    if i == k.lower():
                      industry = key
                      break

      if blog_post_title == "BEESENSE":
        location = "איזור תעשייה, HaCarmel St 2, Yokne'am Illit, 2069207, Israel"
        latitude = 32.6602
        longitude = 35.1046
      elif blog_post_title == "Broshuis | Driving innovation":
        location = "Industrieweg 22, 8263 AD Kampen, Netherlands"
        latitude = 52.5674
        longitude = 5.8950
      elif blog_post_title == "ZEUS Scientific":
        location = "200 Evans Way, Branchburg, NJ 08876, United States"
        latitude = 40.5868
        longitude = 74.6986
      elif  blog_post_title == "Florida Department of Veterans' Affairs":
        location = "Florida - Several Locations"
        latitude = 27.6648
        longitude = 81.5158
      elif blog_post_title == "Tehama County Social Services":
        location = "Tehama County, CA - Several Locations"
        latitude = 40.0982
        longitude = 122.1746
      elif blog_post_title == "Camden City School District":
        location = "Camden"
        latitude = 51.5390
        longitude = 0.1426
      elif blog_post_title == "InfoTek Consulting Services":
        location = "135 Yorkville Ave #700, Toronto, ON M5R 0C7, Canada"
        latitude = 43.6705791
        longitude = -79.3939111
      else:
        address = blog_post_title
        url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'
        response = requests.get(url).json()
        latitude = response[0]["lat"]
        longitude = response[0]["lon"]
        geolocator = Nominatim()
        location = geolocator.reverse(latitude + "," + longitude)

      print(count, blog_post_title, blog_post_date, attacker, industry, latitude, longitude, location, leak_size)
      file = open('IntermediateOutput - Quantum and RansomEXX.csv', 'a', newline='', encoding='utf-8')
      writer = csv.writer(file)
      rows = ([count, blog_post_title, blog_post_date, attacker, industry, latitude, longitude, location, leak_size])
      writer.writerow(rows)
      file.close()
# Out:
# 1 Instituto Agrario Dominicano 2022-09-01 Quantum Ransomware GovernmentAgency 18.422594150000002 -70.11518925 Instituto Agrario Dominicano, Avenida Constitución, Los Molina, San Cristóbal, 91000, República Dominicana 1100000
# 2 Shaw & Slavsky 2022-08-19 Quantum Ransomware Supermarket 42.37064975 -83.18027519891251 11298, Decatur Street, Paveway, Detroit, Wayne County, Michigan, 48227, United States 6000
# 3 BEESENSE 2022-08-04 Quantum Ransomware Security 32.6602 35.1046 איזור תעשייה, HaCarmel St 2, Yokne'am Illit, 2069207, Israel 13000000
# 4 Broshuis | Driving innovation 2022-07-18 Quantum Ransomware Motor/Vehicular 52.5674 5.895 Industrieweg 22, 8263 AD Kampen, Netherlands 117000
# 5 ZEUS Scientific 2022-06-29 Quantum Ransomware Medical 40.5868 74.6986 200 Evans Way, Branchburg, NJ 08876, United States 540000
# ...

# %% [markdown]
# *italicized text*# rnsm777cdsjrsdlbs4v5qoeppu3px6sb2igmh53jzrx7ipcrbjz5b2ad.txt

# %%
with open("/content/rnsm777cdsjrsdlbs4v5qoeppu3px6sb2igmh53jzrx7ipcrbjz5b2ad.txt") as f:
    soup1 = BeautifulSoup(f.read())
    blog_posts1 = soup1.find_all("div", class_="card-body")

    for blog_post1 in blog_posts1:

      blog_post_metadata1 = (blog_post1.find('p', attrs={'class': 'card-text mt-3 text-secondary'}).text)
      blog_post_date1 = blog_post_metadata1[11:21]

      if '2022' not in blog_post_date1:
        break

      if 'leak size: ' in blog_post_metadata1:
        end_index = blog_post_metadata1.index('leak size: ') + 11
        leak_size1 = blog_post_metadata1[end_index:]

      if "G" in leak_size1:
        leak_size1 = ''.join(filter(str.isdigit, leak_size1))
        leak_size1 = int(leak_size1)
        leak_size1 = leak_size1 * 1000
      
      elif "T" in leak_size1:
        leak_size1 = ''.join(filter(str.isdigit, leak_size1))
        leak_size1 = int(leak_size1)
        leak_size1 = leak_size1 * 1000000

      elif "M" in leak_size1:
        leak_size1 = ''.join(filter(str.isdigit, leak_size1))
        leak_size1 = int(leak_size1)

      industry1 = 'none found'
      location1 = 'none found'
      attacker1 = 'RansomEXX Ransomware'
      latitude1 = 0
      longitude1 = 0
      count = count + 1

      blog_post_title1 = (blog_post1.find('h5', attrs={'class': 'card-title'}).text)
      blog_post_title1 = blog_post_title1.lstrip()
      blog_post_title1 = blog_post_title1.rstrip()

      string1 = re.sub(r'[^\w\s]', '', blog_post_title1)
      string2 = string1.replace('of', '')
      txt = (new_string).split() 

      for i in txt: 
        for key in industries:
          for j in industries[key]:
            if i.lower() == j:
              industry = key
              break

      p_tags = soup1.find(class_="card-text").find_next_siblings('p')
      blog_post_para = blog_post1.find(class_="card-text").find_next_siblings('p')
      count_para = 0
      for p in blog_post_para:
        if count_para%2 == 0:
          string3 = p.text
        count_para += 1
      
      string4 = re.sub(r'[^\w\s]', '', string3)
      string5 = string4.replace('of', '')
      txt1 = (string5).split() 

      for k in txt1: 
        for key1 in industries:
          for l in industries[key1]:
            # print(l)
            if k.lower() == l.lower():
              industry1 = key1
              break
      
      if blog_post_title1 == "Scottish Association for Mental Health": 
        location1 = "Scotland - Several Locations"
        latitude1 = 56.4907
        longitude1 = 4.2026
      else:
        if blog_post_title1 == "Bombardier Recreational Products (BRP) - BONUS CONTENT (!!!)":
          address = "Bombardier Recreational Products (BRP)"
          industry1 = "Motor/Vehicular"
        else:
          address = blog_post_title1

        url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(address) +'?format=json'
        response = requests.get(url).json()
        latitude1 = response[0]["lat"]
        longitude1 = response[0]["lon"]
    
        geolocator = Nominatim()
        location1 = geolocator.reverse(latitude1 + "," + longitude1)
              
      print(count, blog_post_title1, blog_post_date1, attacker1, industry1, latitude1, longitude1, location1, leak_size1)
      file = open('IntermediateOutput - Quantum and RansomEXX.csv', 'a', newline='', encoding='utf-8')
      writer = csv.writer(file)
      rows = ([count, blog_post_title1, blog_post_date1, attacker1, industry1, latitude1, longitude1, location1, leak_size1])
      writer.writerow(rows)
      file.close()
# Out:
# 15 Fundo Nacional de Desenvolvimento da Educação 2022-09-03 RansomEXX Ransomware School -15.8008805 -47.88337840605698 Fundo Nacional de Desenvolvimento da Educação, SBS Quadra 02, Setor Bancário Sul, Brasília, Plano Piloto, Região Geográfica Imediata do Distrito Federal, Região Integrada de Desenvolvimento do Distrito Federal e Entorno, Região Geográfica Intermediária do Distrito Federal, Distrito Federal, Região Centro-Oeste, 70070-120, Brasil 6214000
# 16 Bombardier Recreational Products (BRP) - BONUS CONTENT (!!!) 2022-08-24 RansomEXX Ransomware Motor/Vehicular 60.0529433 30.3920382 BRP Центр СЕВЕР, 41, проспект Культуры, округ Северный, Санкт-Петербург, Северо-Западный федеральный округ, 195276, Россия 26000
# 17 Bombardier Recreational Products (BRP) 2022-08-23 RansomEXX Ransomware Motor/Vehicular 60.0529433 30.3920382 BRP Центр СЕВЕР, 41, проспект Культуры, округ Северный, Санкт-Петербург, Северо-Западный федеральный округ, 195276, Россия 2929000
# ...

# %% [markdown]
# # Obtaining Individual data from Quantum

# %% [markdown]
# Changing csv file to dataframe to insert new data

# %%
df = pd.read_csv("IntermediateOutput - Quantum and RansomEXX.csv", usecols=headers)

# %%
with open("/content/institutoagrariodominicano.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/shawslavsky.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/beesense.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/broshuisdrivinginnovation.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/zeusscientific.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/shredstation.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/floridadepartmentofveteransaffairs.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/valleyrentals.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/driveproducts.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/tehamacountysocialservices.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/jetstar.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/infotekconsultingservices.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
with open("/content/maplelodgefarms.txt") as f:
    soup2 = BeautifulSoup(f.read())
    targetName = soup2.find('dd', attrs={'class': 'col-sm-9'}).text
    
    count = len(df.index)
  
    for para2 in soup2.find_all("p"):
      if '2022-09-01' not in para2:
        string = para2.text
        new_string = re.sub(r'[^\w\s]', '', string)
        new_string = new_string.replace('of', '')
        txt = (new_string).split()
        for k in txt:
          for key in dataType:
            for i in dataType[key]:
              if i == k.lower():
                for j in range(count):
                  if (df.iloc[j][1]).lower() == targetName.lower():
                    df.iloc[j, df.columns.get_loc(key)] = 1

# %%
df.head()
# Out:
#    Count               Company Targeted Publish Date            Attacker  \
# 0      1   Instituto Agrario Dominicano   2022-09-01  Quantum Ransomware
# 1      2                 Shaw & Slavsky   2022-08-19  Quantum Ransomware
# 2      3                       BEESENSE   2022-08-04  Quantum Ransomware
# 3      4  Broshuis | Driving innovation   2022-07-18  Quantum Ransomware
# 4      5                ZEUS Scientific   2022-06-29  Quantum Ransomware
#
#            Industry   Latitude  Longitude  \
# 0  GovernmentAgency  18.422594 -70.115189
# 1       Supermarket  42.370650 -83.180275
# 2          Security  32.660200  35.104600
# 3   Motor/Vehicular  52.567400   5.895000
# 4           Medical  40.586800  74.698600
#
#                                   Location of Attack  Leak Size (In MB)  \
# 0  Instituto Agrario Dominicano, Avenida Constitu...            1100000
# 1  11298, Decatur Street, Paveway, Detroit, Wayne...               6000
# ...

# %%
df.to_csv('Quantum and RansomEXX.csv')
